# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a list of all the words.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the validation samples 
# to the words that have a low numeric ID, which by construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal(
        [vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(
        weights=softmax_weights, biases=softmax_biases, inputs=embed, 
        labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.484144
# Nearest to six: acidosis, radcliffe, extraordinary, postmillennialism, coney, gearbox, vfa, contests,
# Nearest to time: conjunctive, ashoka, chaplain, temple, consulates, fandom, tee, kent,
# Nearest to most: available, bred, sheet, lexicon, utraquists, ministry, vasoconstriction, prd,
# Nearest to no: fights, bedouin, airtight, uda, battery, hydraulics, longhorn, hanse,
# Nearest to history: sortavala, kinetochores, atherton, unconvinced, sima, lewes, salads, xviii,
# Nearest to he: uribe, knight, cio, yearbook, novel, ridinghood, sundry, converse,
# Nearest to used: enough, bush, notebook, genghis, sempronius, janet, glastonbury, vc,
# Nearest to such: enrico, hamlin, bahadur, origin, cheek, vertebrae, pilgrim, arboreal,
# Nearest to on: cranberry, denigrating, gadamer, overseer, servile, bash, amd, corgi,
# Nearest to see: becquerel, doom, ticket, fruitarians, monatomic, brutal, dacia, strained,
# Nearest to b: ferguson, regulations, weblog, tos, glutamate, richie, metro, cryptanalyst,
# Nearest to during: zodiac, rashi, serbo, skater, countercultural, oeuvre, ambulance, mano,
# Nearest to was: cervical, vec, neurology, shaftesbury, ponds, buda, premieres, vara,
# Nearest to these: burkert, arcadia, varying, natalie, purification, chilperic, moksha, collective,
# Nearest to is: ponce, discontinuing, langley, milestones, shallower, aladdin, jedi, bebop,
# Nearest to system: diverges, grossed, saber, haida, estonia, anatole, recalls, aki,
# Average loss at step 2000: 4.372909
# Average loss at step 4000: 3.866819
# Average loss at step 6000: 3.787919
# Average loss at step 8000: 3.686192
# Average loss at step 10000: 3.616688
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to time: conjunctive, buchanan, temple, hissing, zimmer, academic, consulates, oscars,
# Nearest to most: available, travelogues, ministry, piped, bred, hurley, hospital, ashley,
# Nearest to no: fights, not, often, it, battery, uda, which, czarist,
# Nearest to history: sortavala, injure, florian, philosophy, atherton, combine, unconvinced, carcinogenic,
# Nearest to he: it, they, she, who, also, daemen, bowser, but,
# Nearest to used: calvin, enough, explosion, hunyadi, exacerbated, prophesy, hf, glycosides,
# Nearest to such: tanaka, known, hamlin, whitlam, oceanographer, atum, gustaf, writing,
# Nearest to on: in, cranberry, during, at, anil, montane, spitfire, muad,
# Nearest to see: doom, fruitarians, versus, claymore, brutal, fung, crookes, nueva,
# Nearest to b: ferguson, glutamate, j, allyn, postcolonial, applet, bgcolor, tripartite,
# Nearest to during: on, in, at, word, haphazard, compost, laid, lapd,
# Nearest to was: is, had, by, has, were, be, gnu, privateers,
# Nearest to these: varying, are, arcadia, all, semitic, enclosures, stubbornly, fugal,
# Nearest to is: was, are, has, mjt, chemicals, be, luton, luxurious,
# Nearest to system: nhl, interception, chun, rockall, bessarabia, diverges, bujold, proportionally,
# Average loss at step 12000: 3.605925
# Average loss at step 14000: 3.569141
# Average loss at step 16000: 3.414458
# Average loss at step 18000: 3.457653
# Average loss at step 20000: 3.539299
# Nearest to six: eight, four, five, seven, nine, three, zero, two,
# Nearest to time: magnetometer, oscars, conjunctive, year, case, atalanta, temple, moko,
# Nearest to most: more, piped, available, some, bred, ministry, assembly, hurley,
# Nearest to no: often, not, a, fights, battery, cabrera, overpowered, flatted,
# Nearest to history: melts, philosophy, sortavala, injure, atherton, carcinogenic, florian, vincenzo,
# Nearest to he: it, she, they, who, anecdotal, ppm, there, never,
# Nearest to used: referred, represented, calvin, signification, enough, hyperinsulinism, glycosides, surged,
# Nearest to such: known, well, tanaka, oceanographer, hamlin, these, tempus, other,
# Nearest to on: in, upon, polo, at, cranberry, through, kilby, earners,
# Nearest to see: doom, fung, encapsulation, me, versus, and, but, crookes,
# Nearest to b: d, ferguson, congregate, adapting, allyn, czech, jamil, apprehended,
# Nearest to during: in, at, with, haphazard, lapd, and, arne, spoof,
# Nearest to was: is, were, has, had, became, be, neopagans, been,
# Nearest to these: some, all, several, both, which, varying, such, fugal,
# Nearest to is: was, has, are, be, were, by, if, ul,
# Nearest to system: proportionally, bujold, interception, nhl, saber, lands, burroughs, rockall,
# Average loss at step 22000: 3.508018
# Average loss at step 24000: 3.486484
# Average loss at step 26000: 3.479906
# Average loss at step 28000: 3.479239
# Average loss at step 30000: 3.505001
# Nearest to six: eight, four, seven, five, nine, three, two, zero,
# Nearest to time: oscars, year, magnetometer, case, motivation, habitual, sophistication, conjunctive,
# Nearest to most: more, some, aesthetically, ashley, bred, use, sunderland, piped,
# Nearest to no: any, a, often, battery, cabrera, czarist, mixed, it,
# Nearest to history: development, melts, injure, roald, informing, philosophy, sortavala, florian,
# Nearest to he: she, it, they, who, there, anecdotal, never, but,
# Nearest to used: referred, known, possible, noted, calvin, represented, written, found,
# Nearest to such: well, known, these, tanaka, oceanographer, tempus, gustaf, including,
# Nearest to on: upon, in, through, cranberry, earners, against, at, spitfire,
# Nearest to see: doom, fung, addresses, but, can, pederastic, esv, beneath,
# Nearest to b: d, czech, rahul, ferguson, j, apprehended, benchmarking, devout,
# Nearest to during: in, after, at, and, on, by, haphazard, arne,
# Nearest to was: is, has, had, were, been, became, when, ulf,
# Nearest to these: some, both, several, many, their, all, such, they,
# Nearest to is: was, has, are, be, were, while, if, when,
# Nearest to system: fulfilled, bujold, icosidodecahedron, motte, diverges, saber, excavations, nhl,
# Average loss at step 32000: 3.497631
# Average loss at step 34000: 3.498971
# Average loss at step 36000: 3.452399
# Average loss at step 38000: 3.302450
# Average loss at step 40000: 3.426596
# Nearest to six: five, four, seven, eight, three, nine, two, one,
# Nearest to time: year, oscars, period, axels, case, conjunctive, keto, zoom,
# Nearest to most: more, aesthetically, nationalistic, piped, ashley, ministry, many, sunderland,
# Nearest to no: any, often, cabrera, lucretia, feinstein, vowel, oils, dougal,
# Nearest to history: informing, melts, development, philosophy, atherton, injure, conclusion, bloodiest,
# Nearest to he: she, it, they, who, there, anecdotal, never, i,
# Nearest to used: known, referred, possible, found, available, considered, written, noted,
# Nearest to such: known, well, these, including, classified, tempus, many, tanaka,
# Nearest to on: upon, through, cranberry, muad, ltc, polo, at, against,
# Nearest to see: can, architectural, fung, including, pederastic, doom, but, equivalence,
# Nearest to b: d, j, metro, tha, c, m, guessing, thunderbolt,
# Nearest to during: after, at, before, in, when, on, against, lapd,
# Nearest to was: is, were, has, had, became, been, when, neopagans,
# Nearest to these: many, some, such, both, several, all, different, their,
# Nearest to is: was, has, are, be, became, cahokia, garments, freshness,
# Nearest to system: systems, icosidodecahedron, diverges, allis, hyperlinks, rockall, apple, documented,
# Average loss at step 42000: 3.435685
# Average loss at step 44000: 3.453334
# Average loss at step 46000: 3.453251
# Average loss at step 48000: 3.355442
# Average loss at step 50000: 3.382693
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to time: year, period, oscars, case, conjunctive, habitual, keto, thing,
# Nearest to most: more, less, many, piped, aesthetically, some, ministry, notion,
# Nearest to no: any, dougal, cabrera, raptor, gide, only, lucretia, oils,
# Nearest to history: informing, unconvinced, melts, florian, conclusion, atherton, tb, legend,
# Nearest to he: she, it, they, who, there, i, koenig, brooding,
# Nearest to used: known, referred, written, found, possible, available, added, considered,
# Nearest to such: well, known, these, part, tanaka, classified, tempus, oceanographer,
# Nearest to on: upon, through, muad, in, ltc, at, polo, earners,
# Nearest to see: architectural, include, including, fung, plotline, commemoration, concerts, slovakian,
# Nearest to b: d, metro, c, tha, devout, m, j, thunderbolt,
# Nearest to during: after, in, eberhard, at, by, when, until, ciboney,
# Nearest to was: is, has, became, were, be, had, been, ul,
# Nearest to these: some, many, both, several, such, different, all, those,
# Nearest to is: was, are, has, be, garments, while, foraging, kerr,
# Nearest to system: systems, icosidodecahedron, diverges, motte, discipleship, fulfilled, apple, bujold,
# Average loss at step 52000: 3.433592
# Average loss at step 54000: 3.426477
# Average loss at step 56000: 3.436573
# Average loss at step 58000: 3.395357
# Average loss at step 60000: 3.395603
# Nearest to six: eight, four, five, nine, seven, three, two, zero,
# Nearest to time: year, case, period, way, oscars, course, thing, results,
# Nearest to most: more, some, less, many, use, piped, aesthetically, notion,
# Nearest to no: any, cabrera, dougal, misses, gide, drafted, cosmo, little,
# Nearest to history: demographics, list, conclusion, elitist, politics, mildly, informing, tb,
# Nearest to he: she, it, they, who, subsequently, there, i, brooding,
# Nearest to used: known, written, referred, called, possible, available, considered, found,
# Nearest to such: well, known, these, tanaka, including, many, classified, part,
# Nearest to on: upon, through, in, muad, lowers, polo, earners, ltc,
# Nearest to see: include, but, fung, including, architectural, interquartile, gravitating, plotline,
# Nearest to b: d, m, p, c, metro, j, f, r,
# Nearest to during: after, in, before, when, following, until, although, ciboney,
# Nearest to was: is, became, had, has, were, been, although, be,
# Nearest to these: many, some, several, both, those, all, such, they,
# Nearest to is: was, are, has, if, biddle, be, became, remains,
# Nearest to system: systems, icosidodecahedron, diverges, allis, fulfilled, motte, technology, surrender,
# Average loss at step 62000: 3.236019
# Average loss at step 64000: 3.255589
# Average loss at step 66000: 3.406290
# Average loss at step 68000: 3.400079
# Average loss at step 70000: 3.362801
# Nearest to six: eight, four, seven, nine, five, three, two, zero,
# Nearest to time: year, conjunctive, period, however, wealth, case, clear, motivation,
# Nearest to most: more, less, some, piped, use, many, notion, highly,
# Nearest to no: any, dougal, misses, little, cabrera, raptor, only, gide,
# Nearest to history: list, demographics, elitist, tb, informing, politics, mistreatment, halting,
# Nearest to he: she, it, they, who, we, subsequently, there, koenig,
# Nearest to used: known, referred, described, written, found, available, possible, seen,
# Nearest to such: well, these, known, classified, many, tanaka, including, some,
# Nearest to on: upon, through, in, at, lowers, muad, within, ltc,
# Nearest to see: include, fung, and, including, but, according, external, references,
# Nearest to b: d, p, m, f, j, r, metro, bart,
# Nearest to during: after, in, before, eberhard, until, when, following, at,
# Nearest to was: is, has, were, became, had, been, when, being,
# Nearest to these: many, such, some, several, those, various, there, are,
# Nearest to is: was, has, are, although, be, contains, makes, became,
# Nearest to system: systems, icosidodecahedron, federation, fulfilled, hauge, diverges, recreated, services,
# Average loss at step 72000: 3.377961
# Average loss at step 74000: 3.350484
# Average loss at step 76000: 3.320786
# Average loss at step 78000: 3.354183
# Average loss at step 80000: 3.377260
# Nearest to six: four, five, eight, seven, three, nine, two, one,
# Nearest to time: year, period, years, bdsm, motivation, cantatas, wealth, flavours,
# Nearest to most: more, piped, many, some, less, use, notion, aesthetically,
# Nearest to no: little, any, dougal, cabrera, another, misses, mixed, raptor,
# Nearest to history: list, melts, elitist, tb, development, witty, legend, informing,
# Nearest to he: she, it, they, who, there, subsequently, we, never,
# Nearest to used: known, referred, available, described, found, written, applied, responsible,
# Nearest to such: well, these, known, classified, follows, described, certain, regarded,
# Nearest to on: upon, in, through, expiry, earners, at, against, procol,
# Nearest to see: include, external, dimethyl, according, cycling, references, links, inertia,
# Nearest to b: d, m, c, p, j, r, f, tupper,
# Nearest to during: after, in, before, when, following, ciboney, until, eberhard,
# Nearest to was: is, became, had, were, has, been, being, loewe,
# Nearest to these: several, many, those, various, such, some, all, both,
# Nearest to is: was, has, are, became, although, makes, ul, does,
# Nearest to system: systems, icosidodecahedron, diverges, recreated, tungsten, republica, uruk, discipleship,
# Average loss at step 82000: 3.405866
# Average loss at step 84000: 3.411019
# Average loss at step 86000: 3.389849
# Average loss at step 88000: 3.351602
# Average loss at step 90000: 3.368570
# Nearest to six: eight, seven, five, four, nine, three, two, zero,
# Nearest to time: year, period, bdsm, wealth, years, day, nod, flavours,
# Nearest to most: more, piped, use, some, less, many, notion, among,
# Nearest to no: any, little, cabrera, only, dougal, oils, nothing, another,
# Nearest to history: list, melts, tb, elitist, development, baptists, informing, carcinogenic,
# Nearest to he: she, they, it, there, subsequently, who, later, soon,
# Nearest to used: referred, known, applied, described, found, designed, available, called,
# Nearest to such: well, known, these, classified, certain, follows, regarded, described,
# Nearest to on: upon, at, under, against, in, lowers, earners, from,
# Nearest to see: external, include, links, references, stan, dimethyl, cycling, list,
# Nearest to b: c, d, j, r, m, f, mechanization, tupper,
# Nearest to during: after, in, before, when, while, at, following, from,
# Nearest to was: is, had, became, were, has, been, be, loewe,
# Nearest to these: several, many, some, such, those, various, are, libertarianism,
# Nearest to is: was, has, are, makes, although, be, includes, became,
# Nearest to system: systems, process, icosidodecahedron, toughest, granddaughter, tungsten, assertion, groupoid,
# Average loss at step 92000: 3.399901
# Average loss at step 94000: 3.251661
# Average loss at step 96000: 3.356406
# Average loss at step 98000: 3.241941
# Average loss at step 100000: 3.357577
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to time: year, thing, period, way, engraving, flavours, habitual, name,
# Nearest to most: more, less, use, piped, some, especially, ministry, skit,
# Nearest to no: any, dougal, little, cabrera, another, motherboards, feinstein, only,
# Nearest to history: list, melts, tb, weinberg, dandridge, carcinogenic, informing, demographics,
# Nearest to he: she, it, they, there, who, we, subsequently, never,
# Nearest to used: referred, applied, designed, described, available, found, written, known,
# Nearest to such: known, well, classified, these, many, certain, regarded, including,
# Nearest to on: upon, earners, at, in, through, muad, against, near,
# Nearest to see: references, links, include, external, can, list, dimethyl, ler,
# Nearest to b: d, bart, j, ferguson, c, french, cc, fijians,
# Nearest to during: after, in, before, following, when, throughout, at, despite,
# Nearest to was: is, became, has, had, were, been, when, although,
# Nearest to these: several, many, some, various, all, those, different, were,
# Nearest to is: was, has, became, are, contains, although, becomes, be,
# Nearest to system: systems, process, technology, icosidodecahedron, toughest, surrender, itself, outbreaks,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))  
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                                                   train_labels, num_sampled, vocabulary_size))
    
    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     490                 as_ref=input_arg.is_ref,
# --> 491                 preferred_dtype=default_dtype)
#     492           except TypeError as err:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype)
#     715         if ret is None:
# --> 716           ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     717
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _TensorTensorConversionFunction(t, dtype, name, as_ref)
#     588         "Tensor conversion requested dtype %s for Tensor with dtype %s: %r"
# --> 589         % (dtype.name, t.dtype.name, str(t)))
#     590   return t
#
# ValueError: Tensor conversion requested dtype int32 for Tensor with dtype float32: 'Tensor("sampled_softmax_loss/Reshape_1:0", shape=(?, 1, ?), dtype=float32, device=/device:CPU:0)'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-0a8ce7e9a905> in <module>()
#      31     # Compute the softmax loss, using a sample of the negative labels each time.
#      32     loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
# ---> 33                                                    train_labels, num_sampled, vocabulary_size))
#      34
#      35     # Optimizer.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py in sampled_softmax_loss(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, remove_accidental_hits, partition_strategy, name)
#    1189       remove_accidental_hits=remove_accidental_hits,
#    1190       partition_strategy=partition_strategy,
# -> 1191       name=name)
#    1192   sampled_losses = nn_ops.softmax_cross_entropy_with_logits(labels=labels,
#    1193                                                             logits=logits)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py in _compute_sampled_logits(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, subtract_log_q, remove_accidental_hits, partition_strategy, name)
#     972     row_wise_dots = math_ops.multiply(
#     973         array_ops.expand_dims(inputs, 1),
# --> 974         array_ops.reshape(true_w, new_true_w_shape))
#     975     # We want the row-wise dot plus biases which yields a
#     976     # [batch_size, num_true] tensor of true_logits.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in multiply(x, y, name)
#     355
#     356 def multiply(x, y, name=None):
# --> 357   return gen_math_ops._mul(x, y, name)
#     358 multiply.__doc__ = gen_math_ops._mul.__doc__.replace("Mul", "`tf.multiply`")
#     359
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _mul(x, y, name)
#    1623     A `Tensor`. Has the same type as `x`.
#    1624   """
# -> 1625   result = _op_def_lib.apply_op("Mul", x=x, y=y, name=name)
#    1626   return result
#    1627
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     520                   "%s type %s of argument '%s'." %
#     521                   (prefix, dtypes.as_dtype(attrs[input_arg.type_attr]).name,
# --> 522                    inferred_from[input_arg.type_attr]))
#     523
#     524           types = [values.dtype]
#
# TypeError: Input 'y' of 'Mul' Op has type float32 that does not match type int32 of argument 'x'.
