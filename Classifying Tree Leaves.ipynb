# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <img src="/Users/desiredewaele/Google Drive/Datasets/Leaves/images/11.jpg">

# %%
path = '/Users/desiredewaele/Google Drive/Datasets/Leaves/'
train = pd.read_csv(path + 'train.csv', index_col=0)
test = pd.read_csv(path + 'test.csv', index_col=0)
train.head()
# Out:
#                   species   margin1   margin2   margin3   margin4   margin5  \
# id
# 1             Acer_Opalus  0.007812  0.023438  0.023438  0.003906  0.011719
# 2   Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625  0.025391
# 3    Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812  0.003906
# 5         Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859  0.021484
# 6      Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766  0.013672
#
#      margin6   margin7  margin8   margin9    ...      texture55  texture56  \
# id                                           ...
# 1   0.009766  0.027344      0.0  0.001953    ...       0.007812   0.000000
# 2   0.001953  0.019531      0.0  0.000000    ...       0.000977   0.000000
# 3   0.005859  0.068359      0.0  0.000000    ...       0.154300   0.000000
# 5   0.019531  0.023438      0.0  0.013672    ...       0.000000   0.000977
# 6   0.015625  0.005859      0.0  0.000000    ...       0.096680   0.000000
#
# ...

# %%
train = train.sample(frac=1)
label = train.pop('species')

# %%
train = train / np.linalg.norm(train, axis=0)
test = test / np.linalg.norm(test, axis=0)
train.head()
# Out:
#       margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# id
# 793  0.007077  0.002576  0.007549  0.028738  0.088046  0.000000  0.009556
# 745  0.082564  0.052808  0.019626  0.000000  0.000000  0.052726  0.000000
# 960  0.000000  0.000000  0.003019  0.016905  0.138736  0.000000  0.000000
# 896  0.007077  0.003864  0.009058  0.013524  0.013341  0.004793  0.054952
# 231  0.068411  0.018032  0.016606  0.010143  0.002668  0.044099  0.038227
#
#       margin8   margin9  margin10    ...      texture55  texture56  texture57  \
# id                                   ...
# 793  0.000000  0.027110  0.010090    ...       0.000000   0.017109   0.000000
# 745  0.000000  0.032531  0.042886    ...       0.000849   0.017109   0.004410
# 960  0.084232  0.081327  0.002523    ...       0.002971   0.000000   0.103632
# 896  0.000000  0.016264  0.045409    ...       0.000000   0.000000   0.006614
# 231  0.000000  0.010843  0.055500    ...       0.075118   0.000000   0.004410
#
# ...

# %%
split = int(len(train)*0.9)
trainX = train.iloc[:split]
validX = train.iloc[split:]
trainY = label.iloc[:split]
validY = label.iloc[split:]
