# %%
ls -l
# Out:
# total 8
# drwxr-xr-x   2 desiredewaele  staff    64 Aug 29  2017 AnacondaProjects/
# drwx------@  4 desiredewaele  staff   128 Feb 21  2017 Applications/
# drwx------   5 desiredewaele  staff   160 Aug 21  2017 Box Sync/
# drwxr-xr-x   5 desiredewaele  staff   160 Jan  2 00:00 Calibre Library/
# drwx------+ 24 desiredewaele  staff   768 Mar 15 14:14 Desktop/
# drwx------+  7 desiredewaele  staff   224 Feb 25  2017 Documents/
# drwx------+ 21 desiredewaele  staff   672 Mar 16 23:59 Downloads/
# drwxr-xr-x   3 desiredewaele  staff    96 May 18  2017 Enviroments/
# drwx------@ 16 desiredewaele  staff   512 Feb  8 20:01 Google Drive/
# drwxr-xr-x   4 desiredewaele  staff   128 Mar  5 09:56 Jagex/
# drwx------+ 70 desiredewaele  staff  2240 Feb 10 01:27 Library/
# drwxr-xr-x   4 desiredewaele  staff   128 May 31  2017 Lily/
# drwx------+  3 desiredewaele  staff    96 Feb 21  2017 Movies/
# drwx------+  3 desiredewaele  staff    96 Feb 21  2017 Music/
# ...

# %%
cat git/portfolio/app/static/css/portfolio.css
# Out:
# @import url('https://fonts.googleapis.com/css?family=Sorts+Mill+Goudy:400');
# body {
#     width: 100%;
#     height: 100%;
#     font-family: Lora, "Noticia Text", Helvetica, Arial, sans-serif;
#     font-size: 16px;
#     color: #000;
#     background-color: #fff;
#     overflow-x: hidden;
#     overflow-y: scroll;
# }
#
# html {
#     width: 100%;
#     height: 100%;
# }
#
# /*********************************************************************************************** TYPOGRAFIE ************************************/
#
# p {
#         margin: 0 0 10px;
#         font-size: 13px;
#         line-height: 1.5;
#         letter-spacing: 0px;
#         -webkit-font-smoothing: subpixel-antialiased;
#         font-family: "Sorts Mill Goudy", Garamond, Palatino, serif;
#         font-style: normal;
#         color: rgba(26, 26, 26, .9);
#     }
#
# h1,
# h2,
# h3,
# h4,
# h5,
# h6 {
#     text-transform: uppercase;
# ...
